# %% [markdown]
# # Forskjeller
#
# Her ser vi på utvalgte ord og tegnsetting som en forskjell mellom skjønnlitteratur og sakprosa

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import pandas as pd

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Merriweather';
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ## Testkorpus

# %% [markdown]
# Sampler noen verk fra tiårene 1970 til 2000. 300 fra dewey 839 og så litt fra andre dewey kategorier.

# %%
romaner = nb.book_corpus(ddk = "839%", period = (1970, 2000), limit = 300)

# %%
sakprosa = pd.concat([nb.book_corpus(ddk = str(x) + '%', limit = 30, period = (1970, 2000)) for x in range(0,9,1) if x != 8 ])

# %% [markdown]
# Vi teller opp ordene i begge korpus

# %%
sagprosa_agg = nb.aggregate_urns(list(sakprosa.urn))

# %%
romaner_agg = nb.aggregate_urns(list(romaner.urn))

# %% [markdown]
# og legger dem i en dataramme

# %%
combo = pd.concat([nb.frame(romaner_agg, 'skjønnlitt'), nb.frame(sagprosa_agg, 'sakprosa')], axis = 1, sort=False).dropna()

# %% [markdown]
# datarammen kan vi så sette opp for å sjekke forholdet mellom bruk av tegn og ord

# %%
combo
# Out:
#     skjønnlitt  sakprosa
# !      51752.0   13440.0
# "       5551.0   44269.0
# #        121.0     748.0
# $         74.0    2487.0
# %        291.0    8035.0
# ..         ...       ...
# ►         21.0    2080.0
# ▼          1.0      11.0
# ★          6.0     368.0
# ♦         17.0     847.0
# ✓          8.0      36.0
#
# [146912 rows x 2 columns]

# %%
combo['ratio'] = combo['skjønnlitt']/combo['sakprosa']

# %% [markdown]
# Lager grupper av tegn og ord

# %%
punktuering = """. , ! " ' ? : ; -""".split()

# %%
pronomen = "vi oss de dem han ham hans hun henne hennes du deg jeg meg".split()

# %%
interjeksjoner = "ja nei jo vel aha åh javel".split()

# %% [markdown]
# Så ser vi på fordelingen i kolonnen _ratio_
#
# Først pronomen

# %%
combo.loc[pronomen]
# Out:
#         skjønnlitt  sakprosa      ratio
# vi         33458.0   33910.0   0.986671
# oss        14397.0   10511.0   1.369708
# de         56533.0   83871.0   0.674047
# dem        18752.0   14287.0   1.312522
# han       117796.0   37385.0   3.150889
# ham        24426.0    9241.0   2.643220
# hans       16305.0    9001.0   1.811465
# hun        50628.0    6726.0   7.527208
# henne      21661.0    2058.0  10.525267
# hennes      8019.0    1546.0   5.186934
# du         47644.0   17468.0   2.727502
# deg        16214.0    6653.0   2.437096
# jeg        86286.0   22737.0   3.794960
# meg        45159.0   10111.0   4.466324

# %% [markdown]
# Så punktuering

# %%
combo.loc[punktuering]
# Out:
#    skjønnlitt  sakprosa     ratio
# .    664861.0  782108.0  0.850088
# ,    535189.0  746233.0  0.717188
# !     51752.0   13440.0  3.850595
# "      5551.0   44269.0  0.125392
# '     18326.0   64638.0  0.283517
# ?     77657.0   99617.0  0.779556
# :     54050.0  101827.0  0.530802
# ;     12526.0   48751.0  0.256938
# -     91894.0  129155.0  0.711502

# %% [markdown]
# Og til slutt interjeksjoner

# %%
combo.loc[interjeksjoner]
# Out:
#        skjønnlitt  sakprosa      ratio
# ja         4944.0    2427.0   2.037083
# nei        2979.0     450.0   6.620000
# jo         9995.0    2976.0   3.358535
# vel       10332.0    2817.0   3.667732
# aha          15.0       5.0   3.000000
# åh           29.0       2.0  14.500000
# javel        49.0       9.0   5.444444

# %% [markdown]
# Sjekker litt med tanke på OCR-feil

# %%
nb.urn_concordance(urns = list(sakprosa.urn), word = '?')
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>- Hjelpe med bøkene våre</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Trenger vi noen hjelp ?</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>? Trenger vi noen hjelp</td>
#                 <td>?</td>
#                 <td style='text-align:left'>år .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>hjelp er det tale om</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Han tar vel ikke Bibliotekaren</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>katalogisere ved bøkene fra oss</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Pedagogisk forskningsinstitutt , som den</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>besøk på UB på Drammensveien</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2
td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:none'>Mot strømmen, Groth, Henrik, 1976</a>
#                 </td>
#                 <td>Cappelen-gården 20 Har forleggerne sjel</td>
#                 <td>?</td>
#                 <td style='text-align:left'>24 Jørgen W . Cappelen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:none'>Mot strømmen, Groth, Henrik, 1976</a>
#                 </td>
#                 <td>er i veien med offiserene</td>
#                 <td>?</td>
#                 <td style='text-align:left'>190</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:none'>Mot strømmen, Groth, Henrik, 1976</a>
#                 </td>
#                 <td>None</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Beiser < ^ tankegang dlev</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:no

# %%
nb.urn_concordance(urns = list(sakprosa.urn), word = '?')
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>- Hjelpe med bøkene våre</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Trenger vi noen hjelp ?</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>? Trenger vi noen hjelp</td>
#                 <td>?</td>
#                 <td style='text-align:left'>år .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>hjelp er det tale om</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Han tar vel ikke Bibliotekaren</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>katalogisere ved bøkene fra oss</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Pedagogisk forskningsinstitutt , som den</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007112800077?searchText=?' target='_blank' style='text-decoration:none'>Samling i et kvart sekel, , 1991</a>
#                 </td>
#                 <td>besøk på UB på Drammensveien</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009031104044?searchText=?' target='_blank' style='text-decoration:none'>Samordning av museumstjenester, Jensen, Inger, 2000</a>
#                 </td>
#                 <td>Samlet eller delt museumstj eneste</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013030506179?searchText=?' target='_blank' style='text-decoration:none'>Forskningsvilkår, Thagaard, Tove, 1989</a>
#                 </td>
#                 <td>U Nasjonalbiblioteket</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Depotbiblioteket</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013030506179?searchText=?' target='_blank' style='text-decoration:none'>Forskningsvilkår, Thagaard, Tove, 1989</a>
#                 </td>
#                 <td>- MELLOM BYRÅKRATI OG MARKED</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013030506179?searchText=?' target='_blank' style='text-decoration:none'>Forskningsvilkår, Thagaard, Tove, 1989</a>
#                 </td>
#                 <td>- ET SÆRPREG VED UNIVERSITETSFORSKNINGEN</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013030506179?searchText=?' target='_blank' style='text-decoration:none'>Forskningsvilkår, Thagaard, Tove, 1989</a>
#                 </td>
#                 <td>Bekrefter våre resultater andre undersøkelser</td>
#                 <td>?</td>
#                 <td style='text-align:left'>7.2 : Diskusjon av undersøkelsens</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013030506179?searchText=?' target='_blank' style='text-decoration:none'>Forskningsvilkår, Thagaard, Tove, 1989</a>
#                 </td>
#                 <td>aktivitet som foregår innenfor forskningsorganisasjonene</td>
#                 <td>?</td>
#                 <td style='text-align:left'>På hvilke mater kan organisering</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016062008063?searchText=?' target='_blank' style='text-decoration:none'>Anmeldelser av norske forfattere i dagspressen 1957-1966, Sande, Erling, 1975</a>
#                 </td>
#                 <td>BAKKE KARI FINNES DU</td>
#                 <td>?</td>
#                 <td style='text-align:left'>AFT.P ( A ) 31.10.1959</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016062008063?searchText=?' target='_blank' style='text-decoration:none'>Anmeldelser av norske forfattere i dagspressen 1957-1966, Sande, Erling, 1975</a>
#                 </td>
#                 <td>BAKKE KARI FINNES DU</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016062008063?searchText=?' target='_blank' style='text-decoration:none'>Anmeldelser av norske forfattere i dagspressen 1957-1966, Sande, Erling, 1975</a>
#                 </td>
#                 <td>BAKKE KARI FINNES DU</td>
#                 <td>?</td>
#                 <td style='text-align:left'>MORGENØL 23.12.1959</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016062008063?searchText=?' target='_blank' style='text-decoration:none'>Anmeldelser av norske forfattere i dagspressen 1957-1966, Sande, Erling, 1975</a>
#                 </td>
#                 <td>FINNES DU</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016062008063?searchText=?' target='_blank' style='text-decoration:none'>Anmeldelser av norske forfattere i dagspressen 1957-1966, Sande, Erling, 1975</a>
#                 </td>
#                 <td>HVA SKAL DU HER NEDE</td>
#                 <td>?</td>
#                 <td style='text-align:left'>MORGENBL 17.11.1966 MAGDA KOCH THOMASSEN</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:none'>Mot strømmen, Groth, Henrik, 1976</a>
#                 </td>
#                 <td>Cappelen-gården 20 Har forleggerne sjel</td>
#                 <td>?</td>
#                 <td style='text-align:left'>24 Jørgen W . Cappelen</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:none'>Mot strømmen, Groth, Henrik, 1976</a>
#                 </td>
#                 <td>er i veien med offiserene</td>
#                 <td>?</td>
#                 <td style='text-align:left'>190</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:none'>Mot strømmen, Groth, Henrik, 1976</a>
#                 </td>
#                 <td>None</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Beiser < ^ tankegang dlev</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060701021?searchText=?' target='_blank' style='text-decoration:no
