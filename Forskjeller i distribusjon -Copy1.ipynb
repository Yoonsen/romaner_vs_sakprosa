# %% [markdown]
# # Forskjeller
#
# Her ser vi på utvalgte ord og tegnsetting som en forskjell mellom skjønnlitteratur og sakprosa

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import pandas as pd
mu.update('get_pdf_word')
# Out:
# Updated file `D:\Documents\GitHub\romaner_vs_sakprosa\get_pdf_word.py`

# %%
import get_pdf_word as wrd

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Merriweather|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Merriweather';
# 	color: DarkSlateGray;
# }
#
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# ## Testkorpus

# %% [markdown]
# Sampler noen verk fra tiårene 1970 til 2000. 300 fra dewey. Skjønnlitteratur fra korpusliste

# %%
romaner = nb.pure_urn(wrd.get_text_from_word('ressurser/Korpus Avstandsblikk på norsk litteraturhistorie.docx'))

# %%
romaner = nb.frame(romaner, 'urn')
romaner.head()
# Out:
#              urn
# 0  2012050708139
# 1  2012050708139
# 2  2015110908267
# 3  2006112101011
# 4  2009061903027

# %%
korpus = pd.read_excel('ressurser/Romanoversikt frem til 1899 med grafer og greier.xlsx')

# %%
korpus.head()
# Out:
#                   Forfatter  \
# 0  Immanuel Christian Grave
# 1    Christian Gran Molberg
# 2       Jacob Nicolai Wilse
# 3              Edvard Storm
# 4         Nicolai Wergeland
#
#                                               Tittel                  Sjanger  \
# 0  En Norsk Hyrdes Indtagelse i et Bierg. Virg. E...                    Fabel
# 1  Zoroaster og Selime : En østerlandsk Fortællin...               Fortelling
# 2  Philoneus eller Efter-Tiiden i Norge : en Fort...                    Fabel
# 3  En nye og sandfærdig Historie om Jesper Hansen...               Fortelling
# 4  Haldor Smeks Tildragelser efter hans hjemkomst...  Ingen sjangerbetegnelse
#
#    Antall sider   Publisert Utgivelsessted   \
# 0           47.0       1771       København
# 1           48.0       1777       Trondhjem
# 2           46.0       1779      Kristiania
# 3          230.0       1791       København
# 4          122.0       1810    Kristiansand
#
#                                                  URN Kjønn Psevdonym  \
# 0                                  Ikke-digitalisert  Mann       NaN
# 1  https://urn.nb.no/URN:NBN:no-nb_digibok_201809...  Mann    Mentor
# 2  https://urn.nb.no/URN:NBN:no-nb_digibok_200912...  Mann       NaN
# 3  http://urn.nb.no/URN:NBN:no-nb_digibok_2009030...  Mann       NaN
# 4                                  Ikke-digitalisert  Mann       NaN
#
#   Psevdonym II Senere utgave   Unnamed: 11  Antall navngitte karakterer
# 0          NaN            NaN          NaN                          NaN
# 1          NaN            NaN          NaN                          NaN
# 2          NaN            NaN          NaN                          NaN
# 3          NaN            NaN          NaN                          NaN
# 4          NaN            NaN          NaN                          NaN

# %%
sakprosa = pd.concat([nb.book_corpus(ddk = str(x) + '%', limit = 30, period = (1970, 2000)) for x in range(0,9,1) if x != 8 ])

# %% [markdown]
# Vi teller opp ordene i begge korpus

# %%
sagprosa_agg = nb.aggregate_urns(list(sakprosa.urn))

# %%
romaner_agg = nb.aggregate_urns(list(romaner.urn))

# %% [markdown]
# og legger dem i en dataramme

# %%
combo = pd.concat([nb.frame(romaner_agg, 'skjønnlitt'), nb.frame(sagprosa_agg, 'sakprosa')], axis = 1, sort=False).dropna()

# %% [markdown]
# datarammen kan vi så sette opp for å sjekke forholdet mellom bruk av tegn og ord

# %%
combo
# Out:
#                   skjønnlitt  sakprosa
# !                    29913.0   14622.0
# "                    24459.0   55292.0
# "Vestfold"               1.0       2.0
# "virkeligheten".         1.0       2.0
# #                      892.0    2583.0
# ...                      ...       ...
# ■                     4127.0    7689.0
# ►                       20.0     259.0
# ▼                        4.0      57.0
# ♦                      637.0     508.0
# ✓                        6.0      31.0
#
# [172722 rows x 2 columns]

# %% [markdown]
# Normaliserer for å se forholdstallene tydelig, så de ikke påvirkes av størrelsen på korpuset

# %%
nb.normalize_corpus_dataframe(combo)
# Out:
# True

# %%
combo['ratio'] = combo['skjønnlitt']/combo['sakprosa']

# %% [markdown]
# Lager grupper av tegn og ord

# %%
punktuering = """. , ! " ' ? : ; -""".split()

# %%
pronomen = "vi oss de dem han ham hans hun henne hennes du deg jeg meg".split()

# %%
interjeksjoner = "ja nei jo vel aha åh javel".split()

# %% [markdown]
# Så ser vi på fordelingen i kolonnen _ratio_
#
# Først pronomen

# %%
combo.loc[pronomen]
# Out:
#         skjønnlitt  sakprosa     ratio
# vi        0.001754  0.002630  0.667005
# oss       0.000404  0.000817  0.494055
# de        0.005733  0.007651  0.749260
# dem       0.000996  0.000898  1.109701
# han       0.009342  0.002076  4.499152
# ham       0.001511  0.000483  3.129687
# hans      0.002544  0.000510  4.992017
# hun       0.001199  0.000554  2.161777
# henne     0.000395  0.000157  2.513892
# hennes    0.000322  0.000101  3.169361
# du        0.000894  0.001354  0.660522
# deg       0.000231  0.000477  0.484158
# jeg       0.001187  0.001698  0.699119
# meg       0.000396  0.000603  0.656930

# %% [markdown]
# Så punktuering

# %%
combo.loc[punktuering]
# Out:
#    skjønnlitt  sakprosa     ratio
# .    0.058677  0.053455  1.097699
# ,    0.054409  0.052197  1.042379
# !    0.001288  0.001088  1.183910
# "    0.001053  0.004114  0.256001
# '    0.001177  0.002598  0.452970
# ?    0.004408  0.010915  0.403816
# :    0.007524  0.006978  1.078339
# ;    0.004849  0.009847  0.492502
# -    0.006397  0.013008  0.491781

# %% [markdown]
# Og til slutt interjeksjoner

# %%
combo.loc[interjeksjoner]
# Out:
#          skjønnlitt      sakprosa     ratio
# ja     1.281934e-04  1.098267e-04  1.167234
# nei    3.871209e-05  4.866304e-05  0.795513
# jo     1.694031e-04  2.683908e-04  0.631181
# vel    3.854415e-04  2.679444e-04  1.438513
# aha    4.306128e-08  1.041717e-06  0.041337
# åh     8.181644e-07  5.952666e-07  1.374450
# javel  3.444903e-07  8.184915e-07  0.420884

# %% [markdown]
# Sjekker litt med tanke på OCR-feil

# %%
nb.urn_concordance(urns = list(sakprosa.urn), word = '?')
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010011104037?searchText=?' target='_blank' style='text-decoration:none'>Veien videre -, Koch, Anette Breder, 1999</a>
#                 </td>
#                 <td>opptatt av ved en fusjon</td>
#                 <td>?</td>
#                 <td style='text-align:left'>13</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010011104037?searchText=?' target='_blank' style='text-decoration:none'>Veien videre -, Koch, Anette Breder, 1999</a>
#                 </td>
#                 <td>kan hindre en effektiv fusjon</td>
#                 <td>?</td>
#                 <td style='text-align:left'>13</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010011104037?searchText=?' target='_blank' style='text-decoration:none'>Veien videre -, Koch, Anette Breder, 1999</a>
#                 </td>
#                 <td>viktige for en vellykket fusjon</td>
#                 <td>?</td>
#                 <td style='text-align:left'>14</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010011104037?searchText=?' target='_blank' style='text-decoration:none'>Veien videre -, Koch, Anette Breder, 1999</a>
#                 </td>
#                 <td>opptatt av ved en fusjon</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010011104037?searchText=?' target='_blank' style='text-decoration:none'>Veien videre -, Koch, Anette Breder, 1999</a>
#                 </td>
#                 <td>kan hindre en effektiv fusjon</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009072300104?searchText=?' target='_blank' style='text-decoration:none'>Avis og avisfolk i Vestfold, Tollnes, Ivar, 1992</a>
#                 </td>
#                 <td>drømme : Er jeg til</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Hvem er jeg i dette</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009072300104?searchText=?' target='_blank' style='text-decoration:none'>Avis og avisfolk i Vestfold, Tollnes, Ivar, 1992</a>
#                 </td>
#                 <td>jeg i dette sære mellomspill</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009072300104?searchText=?' target='_blank' style='text-decoration:none'>Avis og avisfolk i Vestfold, Tollnes, Ivar, 1992</a>
#                 </td>
#                 <td>en tone i det tause</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009072300104?searchText=?' target='_blank' style='text-decoration:none'>Avis og avisfolk i Vestfold, Tollnes, Ivar, 1992</a>
#                 </td>
#                 <td>De første journalistene</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009072300104?searchText=?' target='_blank' style='text-decoration:none'>Avis og avisfolk i Vestfold, Tollnes, Ivar, 1992</a>
#                 </td>
#                 <td>er på ferde i Vestfold</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102208002?searchText=?' target='_blank' style='text-decoration:none'>Bibliografi over diakoni fra Diakonhjemmet[s] høgskolesenter, Trygstad, Hilde, 1998</a>
#                 </td>
#                 <td>Oslo : Diasos , 1980</td>
#                 <td>?</td>
#                 <td style='text-align:left'>. - 7</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102208002?searchText=?' target='_blank' style='text-decoration:none'>Bibliografi over diakoni fra Diakonhjemmet[s] høgskolesenter, Trygstad, Hilde, 1998</a>
#                 </td>
#                 <td>Menighetssøsterhjemmet , 1941</td>
#                 <td>?</td>
#                 <td style='text-align:left'>. - s . 43</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102208002?searchText=?' target='_blank' style='text-decoration:none'>Bibliografi over diakoni fra Diakonhjemmet[s] høgskolesenter, Trygstad, Hilde, 1998</a>
#                 </td>
#                 <td>: Menighetssøsterhj emmet , 1941</td>
#                 <td>?</td>
#                 <td style='text-align:left'>. - s . 35</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102208002?searchText=?' target='_blank' style='text-decoration:none'>Bibliografi over diakoni fra Diakonhjemmet[s] høgskolesenter, Trygstad, Hilde, 1998</a>
#                 </td>
#                 <td>skal omsorgen overleve i menigheten</td>
#                 <td>?</td>
#                 <td style='text-align:left'>" Det norske Diakonhjem ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2010102208002?searchText=?' target='_blank' style='text-decoration:none'>Bibliografi over diakoni fra Diakonhjemmet[s] høgskolesenter, Trygstad, Hilde, 1998</a>
#                 </td>
#                 <td>diakonissa</td>
#                 <td>?</td>
#                 <td style='text-align:left'>. - Stockholm 1951. -</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010508008?searchText=?' target='_blank' style='text-decoration:none'>Erfaringer fra større utbyggingsprosjekter, Buflod, Halvdan, 1976</a>
#                 </td>
#                 <td>ha for vår nasjonale økonomi</td>
#                 <td>?</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010508008?searchText=?' target='_blank' style='text-decoration:none'>Erfaringer fra større utbyggingsprosjekter, Buflod, Halvdan, 1976</a>
#                 </td>
#                 <td>seg for å sikre dem</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Videre kan man spørre om</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010508008?searchText=?' target='_blank' style='text-decoration:none'>Erfaringer fra større utbyggingsprosjekter, Buflod, Halvdan, 1976</a>
#                 </td>
#                 <td>for å holde på ungdommen</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Hvordan skal vi skape et</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016010508008?searchText=?' target='_blank' style='text-decoration:none'>Erfaringer fra større utbyggingsprosjekter, Buflod, Halvdan, 1976</a>
#                 </td>
#                 <td>med muligheter for kvinnelig yrkesdeltakelse</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Hvordan skal servicetilbudet og kommunikasjonene</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www

# %%
nb.urn_concordance(urns = list(romaner.urn), word = '?')
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>blautt Slntet at Sletterne 4</td>
#                 <td>?</td>
#                 <td style='text-align:left'>eb fultentt © folecurftts ffufle</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>tanffe og norffe © fjon</td>
#                 <td>?</td>
#                 <td style='text-align:left'>litcratur Det tetting af et</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>flere Slor brugt at met</td>
#                 <td>?</td>
#                 <td style='text-align:left'>tele mine ( Slcber i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>øberjie Slasfer en nogenlunte fammen</td>
#                 <td>?</td>
#                 <td style='text-align:left'>bcengente og cfter Omftanttigljcterue fulbftønbfg</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>inberegaaentc Untcrboltnirtger met Slcberne tfo</td>
#                 <td>?</td>
#                 <td style='text-align:left'>r om fate batttte met</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>blautt Slntet at Sletterne 4</td>
#                 <td>?</td>
#                 <td style='text-align:left'>eb fultentt © folecurftts ffufle</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>tanffe og norffe © fjon</td>
#                 <td>?</td>
#                 <td style='text-align:left'>litcratur Det tetting af et</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>flere Slor brugt at met</td>
#                 <td>?</td>
#                 <td style='text-align:left'>tele mine ( Slcber i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>øberjie Slasfer en nogenlunte fammen</td>
#                 <td>?</td>
#                 <td style='text-align:left'>bcengente og cfter Omftanttigljcterue fulbftønbfg</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2012050708139?searchText=?' target='_blank' style='text-decoration:none'>Notitser af den norske og danske Literaturhistorie, Boye, O.L., 1861</a>
#                 </td>
#                 <td>inberegaaentc Untcrboltnirtger met Slcberne tfo</td>
#                 <td>?</td>
#                 <td style='text-align:left'>r om fate batttte met</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015110908267?searchText=?' target='_blank' style='text-decoration:none'>norske Literatur fra 1814 indtil vore Dage, Hansen, H. Olaf, 1862</a>
#                 </td>
#                 <td>skaffe med den danske Literatnr</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Hvorfor har ikke Prof .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015110908267?searchText=?' target='_blank' style='text-decoration:none'>norske Literatur fra 1814 indtil vore Dage, Hansen, H. Olaf, 1862</a>
#                 </td>
#                 <td>streng og streng retfærdig Konge</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Han er jo en Stakkel</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015110908267?searchText=?' target='_blank' style='text-decoration:none'>norske Literatur fra 1814 indtil vore Dage, Hansen, H. Olaf, 1862</a>
#                 </td>
#                 <td>norsk Gut fra den Tid</td>
#                 <td>?</td>
#                 <td style='text-align:left'>— Hele Munchs Stykke er</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015110908267?searchText=?' target='_blank' style='text-decoration:none'>norske Literatur fra 1814 indtil vore Dage, Hansen, H. Olaf, 1862</a>
#                 </td>
#                 <td>Linjer i Digtet » Familjelykke</td>
#                 <td>?</td>
#                 <td style='text-align:left'>«</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015110908267?searchText=?' target='_blank' style='text-decoration:none'>norske Literatur fra 1814 indtil vore Dage, Hansen, H. Olaf, 1862</a>
#                 </td>
#                 <td>som har manglet hine Forfattere</td>
#                 <td>?</td>
#                 <td style='text-align:left'>— Vi aftrykker her som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006112101011?searchText=?' target='_blank' style='text-decoration:none'>Norsk Forfatter-Lexicon 1814-1856, Kraft, Jens, 1863</a>
#                 </td>
#                 <td>Chra 1847. VIII . 12</td>
#                 <td>?</td>
#                 <td style='text-align:left'>S . 8. - 2</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006112101011?searchText=?' target='_blank' style='text-decoration:none'>Norsk Forfatter-Lexicon 1814-1856, Kraft, Jens, 1863</a>
#                 </td>
#                 <td>, Eidsvolds-Galleri og foran hani</td>
#                 <td>?</td>
#                 <td style='text-align:left'>Ovrrscettelsr af Snorre . )</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2006112101011?searchText=?' target='_blank' style='text-decoration:none'>Norsk Forfatter-Lexicon 1814-1856, Kraft, Jens, 1863</a>
#                 </td>
#                 <td>187 — 286 0 g</td>
#                 <td>?</td>
#                 <td style='text-align:left'>87 — 437 : H-itadals-</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NB
